# %%
class Book:
    """Represents a book in the library."""

    def __init__(self, book_id, title, author):
        self.book_id = book_id
        self.title = title
        self.author = author
        self.__is_issued = False

# %%
    def issue_book(self):
        """Issue the book if it is currently available."""
        if not self.__is_issued:
            self.__is_issued = True
            print(f"'{self.title}' has been issued.")
        else:
            print(f"'{self.title}' is already issued.")

    def return_book(self):
        """Return the book if it is currently issued."""
        if self.__is_issued:
            self.__is_issued = False
            print(f"'{self.title}' has been returned.")
        else:
            print(f"'{self.title}' is already available.")

    def display_book(self):
        """Display the details and current status of the book."""
        status = "Issued" if self.__is_issued else "Available"

        print(f"ID: {self.book_id}")
        print(f"Title: {self.title}")
        print(f"Author: {self.author}")
        print(f"Status: {status}")

# %%
book1 = Book(101, "Python Basics", "John Smith")
book2 = Book(102, "Data Science Fundamentals", "Sarah Wilson")
book3 = Book(103, "Machine Learning", "David Brown")

# %%
book1.display_book()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 book1.display_book()
#
# AttributeError: 'Book' object has no attribute 'display_book'

# %%
print(Book.__dict__.keys())
# Out:
# dict_keys(['__module__', '__doc__', '__init__', '__dict__', '__weakref__'])

# %%
class Book:
    """Represents a book in the library."""

    def __init__(self, book_id, title, author):
        self.book_id = book_id
        self.title = title
        self.author = author
        self.__is_issued = False

    def issue_book(self):
        """Issue the book if it is currently available."""
        if not self.__is_issued:
            self.__is_issued = True
            print(f"'{self.title}' has been issued.")
        else:
            print(f"'{self.title}' is already issued.")

    def return_book(self):
        """Return the book if it is currently issued."""
        if self.__is_issued:
            self.__is_issued = False
            print(f"'{self.title}' has been returned.")
        else:
            print(f"'{self.title}' is already available.")

    def display_book(self):
        """Display the details and current status of the book."""
        status = "Issued" if self.__is_issued else "Available"

        print(f"ID: {self.book_id}")
        print(f"Title: {self.title}")
        print(f"Author: {self.author}")
        print(f"Status: {status}")

# %%
print(Book.__dict__.keys())
# Out:
# dict_keys(['__module__', '__doc__', '__init__', 'issue_book', 'return_book', 'display_book', '__dict__', '__weakref__'])

# %%
book1 = Book(101, "Python Basics", "John Smith")
book2 = Book(102, "Data Science Fundamentals", "Sarah Wilson")
book3 = Book(103, "Machine Learning", "David Brown")

# %%
book1.display_book()
# Out:
# ID: 101
# Title: Python Basics
# Author: John Smith
# Status: Available

# %%
book1.issue_book()
# Out:
# 'Python Basics' has been issued.

# %%
book1.display_book()
# Out:
# ID: 101
# Title: Python Basics
# Author: John Smith
# Status: Issued

# %%
book1.return_book()
# Out:
# 'Python Basics' has been returned.

# %%
book1.display_book()
# Out:
# ID: 101
# Title: Python Basics
# Author: John Smith
# Status: Available

# %%
class Library:
    """Manages books in the library."""

    def __init__(self):
        self.books = []

    def add_book(self, book):
        """Add a book to the library."""
        self.books.append(book)
        print(f"'{book.title}' added to the library.")

    def view_books(self):
        """Display all books in the library."""
        if not self.books:
            print("No books available.")
            return

        print("\n--- Library Books ---")

        for book in self.books:
            book.display_book()
            print("-" * 30)

    def search_book(self):
        """Search for a book by ID or title."""
        search = input("Enter book ID or title: ").strip()

        for book in self.books:
            if str(book.book_id) == search or book.title.lower() == search.lower():
                print("\nBook found:")
                book.display_book()
                return

        print("Book not found.")

    def issue_book(self):
        """Issue a book using its ID."""
        try:
            book_id = int(input("Enter book ID to issue: "))
        except ValueError:
            print("Invalid ID. Please enter a number.")
            return

        for book in self.books:
            if book.book_id == book_id:
                book.issue_book()
                return

        print("Book not found.")

    def return_book(self):
        """Return a book using its ID."""
        try:
            book_id = int(input("Enter book ID to return: "))
        except ValueError:
            print("Invalid ID. Please enter a number.")
            return

        for book in self.books:
            if book.book_id == book_id:
                book.return_book()
                return

        print("Book not found.")

# %%
library = Library()

# %%
library.add_book(book1)
library.add_book(book2)
library.add_book(book3)
# Out:
# 'Python Basics' added to the library.
# 'Data Science Fundamentals' added to the library.
# 'Machine Learning' added to the library.

# %%
library.view_books()
# Out:
# --- Library Books ---
# ID: 101
# Title: Python Basics
# Author: John Smith
# Status: Available
# ------------------------------
# ID: 102
# Title: Data Science Fundamentals
# Author: Sarah Wilson
# Status: Available
# ------------------------------
# ID: 103
# Title: Machine Learning
# Author: David Brown
# Status: Available
# ------------------------------

# %%
library.search_book()
# Out:
# Enter book ID or title:  101
# Book found:
# ID: 101
# Title: Python Basics
# Author: John Smith
# Status: Available

# %%
library.issue_book()
# Out:
# Enter book ID to issue:  101
# 'Python Basics' has been issued.

# %%
book1.display_book()
# Out:
# ID: 101
# Title: Python Basics
# Author: John Smith
# Status: Issued

# %%
library.return_book()
# Out:
# Enter book ID to return:  101
# 'Python Basics' has been returned.

# %%
book1.display_book()
# Out:
# ID: 101
# Title: Python Basics
# Author: John Smith
# Status: Available

# %%
library = Library()

library.add_book(book1)
library.add_book(book2)
library.add_book(book3)
# Out:
# 'Python Basics' added to the library.
# 'Data Science Fundamentals' added to the library.
# 'Machine Learning' added to the library.

# %%
def main():
    """Run the Library Management System."""

    while True:
        print("\n========== Library Management System ==========")
        print("1. Add Book")
        print("2. View All Books")
        print("3. Search Book")
        print("4. Issue Book")
        print("5. Return Book")
        print("6. Exit")
        print("==============================================")

        choice = input("Enter your choice: ").strip()

        if choice == "1":
            try:
                book_id = int(input("Enter book ID: "))
            except ValueError:
                print("Invalid ID. Please enter a number.")
                continue

            title = input("Enter book title: ").strip()
            author = input("Enter author name: ").strip()

            book = Book(book_id, title, author)
            library.add_book(book)

        elif choice == "2":
            library.view_books()

        elif choice == "3":
            library.search_book()

        elif choice == "4":
            library.issue_book()

        elif choice == "5":
            library.return_book()

        elif choice == "6":
            print("Thank you for using the Library Management System!")
            break

        else:
            print("Invalid choice. Please enter a number from 1 to 6.")

# %%
main()
# Out:
# ========== Library Management System ==========
# 1. Add Book
# 2. View All Books
# 3. Search Book
# 4. Issue Book
# 5. Return Book
# 6. Exit
# ...
# Enter your choice:  2
# --- Library Books ---
# ID: 101
# Title: Python Basics
# Author: John Smith
# Status: Available
# ------------------------------
# ID: 102
# Title: Data Science Fundamentals
# Author: Sarah Wilson
# Status: Available
# ------------------------------
# ID: 103
# Title: Machine Learning
# Author: David Brown
# Status: Available
# ------------------------------
#
# ========== Library Management System ==========
# 1. Add Book
# 2. View All Books
# 3. Search Book
# 4. Issue Book
# 5. Return Book
# 6. Exit
# ...
# Enter your choice:  3
# Enter book ID or title:  101
# Book found:
# ID: 101
# Title: Python Basics
# Author: John Smith
# Status: Available
#
# ========== Library Management System ==========
# 1. Add Book
# 2. View All Books
# 3. Search Book
# 4. Issue Book
# 5. Return Book
# 6. Exit
# ...
# Enter your choice:  4
# ...

# %%
main()
# Out:
# ========== Library Management System ==========
# 1. Add Book
# 2. View All Books
# 3. Search Book
# 4. Issue Book
# 5. Return Book
# 6. Exit
# ...
# Enter your choice:  6
# Thank you for using the Library Management System!
