# %%
# Student Management System (Day 3)

students = []


def add_student():
    student_id = int(input("Enter Student ID: "))


    for student in students:
        if student["id"] == student_id:
            print("Student ID already exists!")
            return

    name = input("Enter Name: ")
    age = int(input("Enter Age: "))
    course = input("Enter Course: ")

    marks = list(map(int, input("Enter marks (space separated): ").split()))

    student = {
        "id": student_id,
        "name": name,
        "age": age,
        "course": course,
        "marks": marks
    }

    students.append(student)
    print("Student added successfully")



def view_students():
    if not students:
        print("No students found.")
        return

    print("\n Student Records ")
    for student in students:
        average = sum(student["marks"]) / len(student["marks"])
        print(f"""
ID      : {student['id']}
Name    : {student['name']}
Age     : {student['age']}
Course  : {student['course']}
Marks   : {student['marks']}
Average : {average:.2f}
""")



def search_student():
    search = input("Enter Student ID or Name: ").lower()

    found = False

    for student in students:
        if str(student["id"]) == search or student["name"].lower() == search:
            print(student)
            found = True

    if not found:
        print("Student not found")



def update_student():
    student_id = int(input("Enter Student ID to update: "))

    for student in students:
        if student["id"] == student_id:
            student["name"] = input("Enter New Name: ")
            student["age"] = int(input("Enter New Age: "))
            student["course"] = input("Enter New Course: ")
            student["marks"] = list(map(int, input("Enter New Marks: ").split()))

            print("Student updated successfully")
            return

    print("Student not found")



def delete_student():
    student_id = int(input("Enter Student ID to delete: "))

    for student in students:
        if student["id"] == student_id:
            students.remove(student)
            print("Student deleted successfully")
            return

    print("Student not found")



while True:

    print("""
Student Management System 
1. Add Student
2. View Students
3. Search Student
4. Update Student
5. Delete Student
6. Exit
""")

    choice = input("Enter your choice: ")

    if choice == "1":
        add_student()

    elif choice == "2":
        view_students()

    elif choice == "3":
        search_student()

    elif choice == "4":
        update_student()

    elif choice == "5":
        delete_student()

    elif choice == "6":
        print("Thank you!")
        break

    else:
        print("Invalid choice! Try again.")
# Out:
# Student Management System
# 1. Add Student
# 2. View Students
# 3. Search Student
# 4. Update Student
# 5. Delete Student
# 6. Exit
# Enter your choice:  1
# Enter Student ID:  1
# Enter Name:  Madhav
# Enter Age:  21
# Enter Course:  AIML
# Enter marks (space separated):  5 0
# Student added successfully
#
# Student Management System
# 1. Add Student
# 2. View Students
# 3. Search Student
# 4. Update Student
# 5. Delete Student
# 6. Exit
# Enter your choice:  2
#  Student Records
#
# ID      : 1
# Name    : Madhav
# Age     : 21
# Course  : AIML
# Marks   : [5, 0]
# Average : 2.50
#
#
# Student Management System
# 1. Add Student
# 2. View Students
# 3. Search Student
# 4. Update Student
# 5. Delete Student
# 6. Exit
