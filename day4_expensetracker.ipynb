# %%
import csv
import os

FILE = "expenses.csv"

# %%
def init_file():
    if not os.path.exists(FILE):
        with open(FILE, "w", newline="") as f:
            writer = csv.writer(f)
            writer.writerow(["date", "category", "amount", "note"])

init_file()

# %%
def add_expense():
    date = input("Date (YYYY-MM-DD): ")
    category = input("Category: ")
    
    try:
        amount = float(input("Amount: "))
    except ValueError:
        print("Invalid amount. Please enter a number.")
        return
    
    note = input("Note (optional): ")

    with open(FILE, "a", newline="") as f:
        writer = csv.writer(f)
        writer.writerow([date, category, amount, note])

    print("Expense added.")

# %%
def view_expenses():
    total = 0

    try:
        with open(FILE, "r", newline="") as f:
            reader = csv.DictReader(f)

            print("\n--- All Expenses ---")

            for row in reader:
                amount = float(row["amount"])
                total += amount

                print(
                    f'{row["date"]} | '
                    f'{row["category"]} | '
                    f'{amount:.2f} | '
                    f'{row["note"]}'
                )

        print(f"\nTotal spent: {total:.2f}")

    except FileNotFoundError:
        print("Expense file not found.")

# %%
def category_summary():
    summary = {}

    try:
        with open(FILE, "r", newline="") as f:
            reader = csv.DictReader(f)

            for row in reader:
                category = row["category"]
                amount = float(row["amount"])

                if category in summary:
                    summary[category] += amount
                else:
                    summary[category] = amount

        print("\n--- Category Summary ---")

        for category, amount in summary.items():
            print(f"{category}: {amount:.2f}")

    except FileNotFoundError:
        print("Expense file not found.")

# %%
def main():
    while True:
        print("\n=== Expense Tracker ===")
        print("1. Add Expense")
        print("2. View All Expenses")
        print("3. Category Summary")
        print("4. Exit")

        choice = input("Enter choice: ")

        if choice == "1":
            add_expense()

        elif choice == "2":
            view_expenses()

        elif choice == "3":
            category_summary()

        elif choice == "4":
            print("Goodbye!")
            break

        else:
            print("Invalid choice. Please try again.")


main()
# Out:
# === Expense Tracker ===
# 1. Add Expense
# 2. View All Expenses
# 3. Category Summary
# 4. Exit
# Enter choice:  1
# Date (YYYY-MM-DD):  2026-08-09
# Category:  Food
# Amount:  180
# Note (optional):  Lunch
# Expense added.
#
# === Expense Tracker ===
# 1. Add Expense
# 2. View All Expenses
# 3. Category Summary
# 4. Exit
# Enter choice:  1
# Date (YYYY-MM-DD):  2026-08-09
# Category:  Travel
# Amount:  60
# Note (optional):  Bus
# Expense added.
#
# === Expense Tracker ===
# 1. Add Expense
# 2. View All Expenses
# 3. Category Summary
# 4. Exit
# Enter choice:  2
# --- All Expenses ---
# 2026-08-09 | Food | 180.00 | Lunch
# 2026-08-09 | Travel | 60.00 | Bus
#
# Total spent: 240.00
#
# === Expense Tracker ===
# 1. Add Expense
# 2. View All Expenses
# 3. Category Summary
# 4. Exit
# Enter choice:  3
# --- Category Summary ---
# Food: 180.00
# Travel: 60.00
#
# === Expense Tracker ===
# 1. Add Expense
# 2. View All Expenses
# 3. Category Summary
# 4. Exit
# Enter choice:  4
# Goodbye!
